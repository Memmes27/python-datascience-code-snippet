# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'a':[1,2,3,4], 'b':[2,3,4,5]})

print(df.agg({'a':[sum,np.max, np.mean, np.min], 'b':[np.max,np.mean]}, ))
# Out:
#          a    b
# sum   10.0  NaN
# amax   4.0  5.0
# mean   2.5  3.5
# amin   1.0  NaN
