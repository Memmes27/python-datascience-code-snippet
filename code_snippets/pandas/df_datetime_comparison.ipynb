# %%
import pandas as pd

df = pd.DataFrame({'date': pd.date_range(start='2021-7-19', end='2021-7-23'), 'value': list(range(2,11,2))})
df
# Out:
#         date  value
# 0 2021-07-19      2
# 1 2021-07-20      4
# 2 2021-07-21      6
# 3 2021-07-22      8
# 4 2021-07-23     10

# %%
filtered_df = df[df.date <= '2021-07-21']
filtered_df
# Out:
#         date  value
# 0 2021-07-19      2
# 1 2021-07-20      4
# 2 2021-07-21      6
